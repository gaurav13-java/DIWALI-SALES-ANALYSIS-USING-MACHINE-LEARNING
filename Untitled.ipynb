# %%
import pandas as pd 
import numpy as np 
import plotly.express as px 
import plotly.graph_objects as go

# %%
# import csv file
df = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.drop(columns=['Status','unnamed1','Age Group'], inplace=True)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
df.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11239 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11239 non-null  int64
#  1   Cust_name         11239 non-null  object
#  2   Product_ID        11239 non-null  object
#  3   Gender            11239 non-null  object
#  4   Age               11239 non-null  int64
#  5   Marital_Status    11239 non-null  int64
#  6   State             11239 non-null  object
#  7   Zone              11239 non-null  object
#  8   Occupation        11239 non-null  object
#  9   Product_Category  11239 non-null  object
#  10  Orders            11239 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
df.groupby('State').first()
# Out:
#                   User_ID     Cust_name Product_ID Gender  Age  \
# State
# Andhra Pradesh    1000732        Kartik  P00110942      F   35
# Bihar             1001912         Hazel  P00087442      F   27
# Delhi             1003829      Harshita  P00200842      M   34
# Gujarat           1000588          Joni  P00057942      M   28
# Haryana           1003745       Shivani  P00220042      M   29
# Himachal Pradesh  1000588          Joni  P00057942      M   28
# Jharkhand         1004957    Inderpreet  P00111842      M   27
# Karnataka         1001425        Sudevi  P00237842      M   16
# Kerala            1000687         Neola  P00156442      M   35
# Madhya Pradesh    1000438       Bhosale  P00182542      F   25
# Maharashtra       1002903     Sanskriti  P00125942      F   28
# Punjab            1006009        Aditya  P00148642      M   28
# Rajasthan         1000838  Divyeshkumar  P00363542      M   53
# Telangana         1003580       Maxwell  P00018042      M   20
# ...

# %%
df['State'] = df['State'].str.replace('Andhra\xa0Pradesh', 'Andhra Pradesh')

# %%
df['State']
# Out:
# 0           Maharashtra
# 1        Andhra Pradesh
# 2         Uttar Pradesh
# 3             Karnataka
# 4               Gujarat
#               ...
# 11246       Maharashtra
# 11247           Haryana
# 11248    Madhya Pradesh
# 11249         Karnataka
# 11250       Maharashtra
# Name: State, Length: 11239, dtype: object

# %%
states =list(set(df['State'].unique()))

# %%
states
# Out:
# ['Karnataka',
#  'Madhya Pradesh',
#  'Punjab',
#  'Maharashtra',
#  'Delhi',
#  'Andhra Pradesh',
#  'Telangana',
#  'Uttar Pradesh',
#  'Haryana',
#  'Jharkhand',
#  'Bihar',
#  'Rajasthan',
#  'Gujarat',
#  'Kerala',
#  'Himachal Pradesh',
#  'Uttarakhand']

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount
# 0   Western       Healthcare             Auto       1  23952.0
# 1  Southern             Govt             Auto       3  23934.0
# 2   Central       Automobile             Auto       3  23924.0
# 3  Southern     Construction             Auto       2  23912.0
# 4   Western  Food Processing             Auto       2  23877.0

# %%
Occupation = list(set(df['Occupation'].unique()))

# %%
Occupation
# Out:
# ['Automobile',
#  'Media',
#  'Healthcare',
#  'Food Processing',
#  'IT Sector',
#  'Chemical',
#  'Banking',
#  'Retail',
#  'Textile',
#  'Hospitality',
#  'Agriculture',
#  'Lawyer',
#  'Construction',
#  'Govt',
#  'Aviation']

# %%
df['Product_Category'] = df['Product_Category'].str.split(' & ').str[0]

# %%
product_cat = list(set(df['Product_Category'].unique()))

# %%
zones = list(set(df['Zone'].unique()))

# %%
zones
# Out:
# ['Northern', 'Eastern', 'Southern', 'Central', 'Western']

# %%
product_cat
# Out:
# ['Furniture',
#  'Pet Care',
#  'Tupperware',
#  'Electronics',
#  'Office',
#  'Games',
#  'Books',
#  'Auto',
#  'Household items',
#  'Stationery',
#  'Veterinary',
#  'Hand',
#  'Sports Products',
#  'Clothing',
#  'Beauty',
#  'Footwear',
#  'Decor',
#  'Food']

# %% [markdown]
# ## Zone Wise Analysis

# %%
def ZoneWise(zone):
    pass

# %%
zone = 'Southern'
zone_df = df[df['Zone'] == zone]
zone_states = zone_df['State'].unique().tolist()
select_zone_state = zone_states[0]

# %% [markdown]
# #### Total Amount Selected States

# %%
total_amount_expense = zone_df[zone_df['State'] == select_zone_state]['Amount'].sum()
total_amount_expense
# Out:
# 8037146.99

# %% [markdown]
# #### Zone States Expense

# %%
zone_states_expense = zone_df.groupby('State')['Amount'].sum().reset_index()
zone_states_expense
# Out:
#             State       Amount
# 0  Andhra Pradesh   8037146.99
# 1       Karnataka  13523540.00
# 2          Kerala   3894491.99
# 3       Telangana   1151490.00

# %%
zone_df
# Out:
#        User_ID Cust_name Product_ID Gender  Age  Marital_Status  \
# 1      1000732    Kartik  P00110942      F   35               1
# 3      1001425    Sudevi  P00237842      M   16               0
# 9      1003650     Ginny  P00031142      F   26               1
# 11     1000214  Kargatis  P00119142      F   20               0
# 12     1004035    Elijah  P00080342      F   20               1
# ...        ...       ...        ...    ...  ...             ...
# 11200  1000814     Hwang  P00144042      M   19               0
# 11218  1003606       Meg  P00157542      M   32               0
# 11235  1001248   Calhoun  P00255842      M   39               0
# 11238  1002718  Abhishek  P00003442      M   28               0
# 11249  1004023    Noonan  P00059442      M   37               0
#
#                 State      Zone    Occupation Product_Category  Orders  \
# 1      Andhra Pradesh  Southern          Govt             Auto       3
# ...

# %%
ldf = pd.read_csv("Latitude and Longitude State wise centroids 2020.csv")

# %%
merged_df = pd.merge(ldf, zone_df, left_on='State',right_on='State', how='inner')

# %%
map = merged_df.groupby('State')[["Longitude","Latitude"]].first().reset_index()
# Out:
#             State  Longitude   Latitude
# 0  Andhra Pradesh  79.740000  15.912900
# 1       Karnataka  76.299625  14.369817
# 2          Kerala  76.217706  10.326706
# 3       Telangana  79.019300  18.112400

# %%
merged_df
# Out:
#       ilist           State  Longitude  Latitude  User_ID Cust_name  \
# 0         1  Andhra Pradesh    79.7400   15.9129  1000732    Kartik
# 1         1  Andhra Pradesh    79.7400   15.9129  1003650     Ginny
# 2         1  Andhra Pradesh    79.7400   15.9129  1000214  Kargatis
# 3         1  Andhra Pradesh    79.7400   15.9129  1004035    Elijah
# 4         1  Andhra Pradesh    79.7400   15.9129  1001680   Vasudev
# ...     ...             ...        ...       ...      ...       ...
# 2688     32       Telangana    79.0193   18.1124  1002895     Carol
# 2689     32       Telangana    79.0193   18.1124  1004526   Shefali
# 2690     32       Telangana    79.0193   18.1124  1000721    Deepak
# 2691     32       Telangana    79.0193   18.1124  1004085    Frazer
# 2692     32       Telangana    79.0193   18.1124  1002002   Maureen
#
#      Product_ID Gender  Age  Marital_Status      Zone   Occupation  \
# 0     P00110942      F   35               1  Southern         Govt
# ...

# %%
df.groupby('Orders').first()
# Out:
#         User_ID  Cust_name Product_ID Gender  Age  Marital_Status  \
# Orders
# 1       1002903  Sanskriti  P00125942      F   28               0
# 2       1001425     Sudevi  P00237842      M   16               0
# 3       1000732     Kartik  P00110942      F   35               1
# 4       1001132       Balk  P00018042      F   25               1
#
#                  State      Zone    Occupation Product_Category   Amount
# Orders
# 1          Maharashtra   Western    Healthcare             Auto  23952.0
# 2            Karnataka  Southern  Construction             Auto  23912.0
# 3       Andhra Pradesh  Southern          Govt             Auto  23934.0
# 4        Uttar Pradesh   Central        Lawyer             Auto  23841.0

# %%
df.groupby('Orders')['Amount'].sum().reset_index()
# Out:
#    Orders       Amount
# 0       1  26851917.50
# 1       2  27392963.45
# 2       3  25996040.99
# 3       4  26008210.49
